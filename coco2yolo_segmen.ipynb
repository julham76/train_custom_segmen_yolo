# %%
# Unzip images to a custom data folder # TIDAK DIGUNAKAN
# !unzip -q /content/datasegmen.zip -d /content/custom_data

# %% [markdown]
# 1. UPLOAD TERLEBIH DAHULU FILE "ANNOTATIONS.JSON" KE FOLDER DEFAULT
# 2. LALU BUATKAN FOLDER BARU, MISALKAN BERNAMA 2

# %%
#"""
#Author: Zubin Bhuyan
#Date: June 21, 2023

#MIT License

#"""

import json
import os

def convert_coco_to_yolo_segmentation(json_file, folder_name = "labels"):
    folder_name = folder_name
    # Load the JSON file
    with open(json_file, 'r') as file:
        coco_data = json.load(file)

    # Create a "labels" folder to store YOLO segmentation annotations
    output_folder = os.path.join(os.path.dirname(json_file), folder_name)
    os.makedirs(output_folder, exist_ok=True)

    # Extract annotations from the COCO JSON data
    annotations = coco_data['annotations']
    for annotation in annotations:
        image_id = annotation['image_id']
        category_id = annotation['category_id']
        segmentation = annotation['segmentation']
        bbox = annotation['bbox']

        # Find the image filename from the COCO data
        for image in coco_data['images']:
            if image['id'] == image_id:
                image_filename = os.path.basename(image['file_name'])
                image_filename = os.path.splitext(image_filename)[0] # Removing the extension. (In our case, it is the .jpg or .png part.)
                image_width = image['width']
                image_height = image['height']
                break

        # Calculate the normalized center coordinates and width/height
        x_center = (bbox[0] + bbox[2] / 2) / image_width
        y_center = (bbox[1] + bbox[3] / 2) / image_height
        bbox_width = bbox[2] / image_width
        bbox_height = bbox[3] / image_height

        # Convert COCO segmentation to YOLO segmentation format
        yolo_segmentation = [f"{(x) / image_width:.5f} {(y) / image_height:.5f}" for x, y in zip(segmentation[0][::2], segmentation[0][1::2])]
        #yolo_segmentation.append(f"{(segmentation[0][0]) / image_width:.5f} {(segmentation[0][1]) / image_height:.5f}")
        yolo_segmentation = ' '.join(yolo_segmentation)

        # Generate the YOLO segmentation annotation line
        yolo_annotation = f"{category_id} {yolo_segmentation}"

        # Save the YOLO segmentation annotation in a file
        output_filename = os.path.join(output_folder, f"{image_filename}.txt")
        with open(output_filename, 'a+') as file:
            file.write(yolo_annotation + '\n')

    print("Conversion completed. YOLO segmentation annotations saved in 'labels' folder.")




# Example usage
json_file = "/content/annotations.json" #JSON file
split = "/content/2" #Folder
convert_coco_to_yolo_segmentation(json_file, split)
# Out:
# Conversion completed. YOLO segmentation annotations saved in 'labels' folder.

# %%
# Zip into "my_model.zip"
# !zip /content/my_data.zip -r /content/2
#%cd /content
#!rm -rf [nama folder yang mau dihapus]
# Out:
#   adding: content/2/ (stored 0%)
#   adding: content/2/p100376.txt (deflated 59%)
#   adding: content/2/p100886.txt (deflated 59%)
#   adding: content/2/p101711.txt (deflated 59%)
#   adding: content/2/p101951.txt (deflated 59%)
#   adding: content/2/p101921.txt (deflated 59%)
#   adding: content/2/p101471.txt (deflated 59%)
#   adding: content/2/p100346.txt (deflated 59%)
#   adding: content/2/p101576.txt (deflated 59%)
#   adding: content/2/p100691.txt (deflated 59%)
#   adding: content/2/p100766.txt (deflated 59%)
#   adding: content/2/p101291.txt (deflated 59%)
#   adding: content/2/p100046.txt (deflated 59%)
#   adding: content/2/p100091.txt (deflated 59%)
#   adding: content/2/p100496.txt (deflated 59%)
#   adding: content/2/p100466.txt (deflated 59%)
#   adding: content/2/p100571.txt (deflated 59%)
#   adding: content/2/p101786.txt (deflated 59%)
#   adding: content/2/p101666.txt (deflated 59%)
#   adding: content/2/p101186.txt (deflated 59%)
#   adding: content/2/p100541.txt (deflated 59%)
#   adding: content/2/p101516.txt (deflated 59%)
#   adding: content/2/p101906.txt (deflated 59%)
#   adding: content/2/p101696.txt (deflated 59%)
#   adding: content/2/p100076.txt (deflated 59%)
#   adding: content/2/p101486.txt (deflated 59%)
#   adding: content/2/p102041.txt (deflated 59%)
#   adding: content/2/p101261.txt (deflated 59%)
#   adding: content/2/p101606.txt (deflated 59%)
#   adding: content/2/p101501.txt (deflated 59%)
#   adding: content/2/p101246.txt (deflated 59%)
#   adding: content/2/p100586.txt (deflated 59%)
#   adding: content/2/p101561.txt (deflated 59%)
#   adding: content/2/p101441.txt (deflated 59%)
#   adding: content/2/p100811.txt (deflated 59%)
#   adding: content/2/p101651.txt (deflated 59%)
#   adding: content/2/p100451.txt (deflated 59%)
#   adding: content/2/p101426.txt (deflated 59%)
#   adding: content/2/p101966.txt (deflated 59%)
#   adding: content/2/p100421.txt (deflated 59%)
#   adding: content/2/p101006.txt (deflated 59%)
#   adding: content/2/p101216.txt (deflated 59%)
#   adding: content/2/p100121.txt (deflated 59%)
#   adding: content/2/p101201.txt (deflated 59%)
#   adding: content/2/p100196.txt (deflated 59%)
#   adding: content/2/p100061.txt (deflated 59%)
#   adding: content/2/p100661.txt (deflated 59%)
#   adding: content/2/p102026.txt (deflated 59%)
#   adding: content/2/p100616.txt (deflated 59%)
#   adding: content/2/p100256.txt (deflated 59%)
#   adding: content/2/p100991.txt (deflated 59%)
#   adding: content/2/p100856.txt (deflated 59%)
#   adding: content/2/p100016.txt (deflated 59%)
#   adding: content/2/p101396.txt (deflated 59%)
#   adding: content/2/p101546.txt (deflated 59%)
#   adding: content/2/p100406.txt (deflated 59%)
#   adding: content/2/p101981.txt (deflated 59%)
#   adding: content/2/p100631.txt (deflated 59%)
#   adding: content/2/p101531.txt (deflated 59%)
#   adding: content/2/p100916.txt (deflated 59%)
#   adding: content/2/p100286.txt (deflated 59%)
#   adding: content/2/p100676.txt (deflated 59%)
#   adding: content/2/p101456.txt (deflated 59%)
#   adding: content/2/p100301.txt (deflated 59%)
#   adding: content/2/p101306.txt (deflated 59%)
#   adding: content/2/p101036.txt (deflated 59%)
#   adding: content/2/p100511.txt (deflated 59%)
#   adding: content/2/p101831.txt (deflated 59%)
#   adding: content/2/p100871.txt (deflated 59%)
#   adding: content/2/p100271.txt (deflated 59%)
#   adding: content/2/p100826.txt (deflated 59%)
#   adding: content/2/p100316.txt (deflated 59%)
#   adding: content/2/p100946.txt (deflated 59%)
#   adding: content/2/p101591.txt (deflated 59%)
#   adding: content/2/p101621.txt (deflated 59%)
#   adding: content/2/p101081.txt (deflated 59%)
#   adding: content/2/p101111.txt (deflated 59%)
#   adding: content/2/p100481.txt (deflated 59%)
#   adding: content/2/p101336.txt (deflated 59%)
#   adding: content/2/p100331.txt (deflated 59%)
#   adding: content/2/p100781.txt (deflated 59%)
#   adding: content/2/p100391.txt (deflated 59%)
#   adding: content/2/p101276.txt (deflated 59%)
#   adding: content/2/p101876.txt (deflated 59%)
#   adding: content/2/p101366.txt (deflated 59%)
#   adding: content/2/p100706.txt (deflated 59%)
#   adding: content/2/p101681.txt (deflated 59%)
#   adding: content/2/p101996.txt (deflated 59%)
#   adding: content/2/p100646.txt (deflated 59%)
#   adding: content/2/p100931.txt (deflated 59%)
#   adding: content/2/p101051.txt (deflated 59%)
#   adding: content/2/p101636.txt (deflated 59%)
#   adding: content/2/p100241.txt (deflated 59%)
#   adding: content/2/p101231.txt (deflated 59%)
#   adding: content/2/p100001.txt (deflated 59%)
#   adding: content/2/p101411.txt (deflated 59%)
#   adding: content/2/p101801.txt (deflated 59%)
#   adding: content/2/p101846.txt (deflated 59%)
#   adding: content/2/p101861.txt (deflated 59%)
#   adding: content/2/p100721.txt (deflated 59%)
#   adding: content/2/p101321.txt (deflated 59%)
#   adding: content/2/p101381.txt (deflated 59%)
#   adding: content/2/p101096.txt (deflated 59%)
#   adding: content/2/p100226.txt (deflated 59%)
#   adding: content/2/p101936.txt (deflated 59%)
#   adding: content/2/p100181.txt (deflated 59%)
#   adding: content/2/p100436.txt (deflated 59%)
#   adding: content/2/p101141.txt (deflated 59%)
#   adding: content/2/p100961.txt (deflated 59%)
#   adding: content/2/p100601.txt (deflated 59%)
#   adding: content/2/p100106.txt (deflated 59%)
#   adding: content/2/p101726.txt (deflated 59%)
#   adding: content/2/p101066.txt (deflated 59%)
#   adding: content/2/p101171.txt (deflated 59%)
#   adding: content/2/p101741.txt (deflated 59%)
#   adding: content/2/p100361.txt (deflated 59%)
#   adding: content/2/p102011.txt (deflated 59%)
#   adding: content/2/p100526.txt (deflated 59%)
#   adding: content/2/p100901.txt (deflated 59%)
#   adding: content/2/p100751.txt (deflated 59%)
#   adding: content/2/p100976.txt (deflated 59%)
#   adding: content/2/p101771.txt (deflated 59%)
#   adding: content/2/p100031.txt (deflated 59%)
#   adding: content/2/p101126.txt (deflated 59%)
#   adding: content/2/p100211.txt (deflated 59%)
#   adding: content/2/p100841.txt (deflated 59%)
#   adding: content/2/p101021.txt (deflated 59%)
#   adding: content/2/p100556.txt (deflated 59%)
#   adding: content/2/p101156.txt (deflated 59%)
#   adding: content/2/p100136.txt (deflated 59%)
#   adding: content/2/p101351.txt (deflated 59%)
#   adding: content/2/p100796.txt (deflated 59%)
#   adding: content/2/p101891.txt (deflated 59%)
#   adding: content/2/p101816.txt (deflated 59%)
#   adding: content/2/p100736.txt (deflated 59%)
#   adding: content/2/p101756.txt (deflated 59%)
#   adding: content/2/p100151.txt (deflated 59%)
#   adding: content/2/p100166.txt (deflated 59%)
